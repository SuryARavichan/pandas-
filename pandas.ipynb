# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryARavichan/pandas-/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('house prediction.csv')

# %%
df.head()
# Out:
#               area_type   availability  ... balcony   price
# 0  Super built-up  Area         19-Dec  ...     1.0   39.07
# 1            Plot  Area  Ready To Move  ...     3.0  120.00
# 2        Built-up  Area  Ready To Move  ...     3.0   62.00
# 3  Super built-up  Area  Ready To Move  ...     1.0   95.00
# 4  Super built-up  Area  Ready To Move  ...     1.0   51.00
#
# [5 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.head(5)
# Out:
#               area_type   availability  ... balcony   price
# 0  Super built-up  Area         19-Dec  ...     1.0   39.07
# 1            Plot  Area  Ready To Move  ...     3.0  120.00
# 2        Built-up  Area  Ready To Move  ...     3.0   62.00
# 3  Super built-up  Area  Ready To Move  ...     1.0   95.00
# 4  Super built-up  Area  Ready To Move  ...     1.0   51.00
#
# [5 rows x 9 columns]

# %%
df.tail(10)
# Out:
#                   area_type   availability  ... balcony   price
# 13310  Super built-up  Area  Ready To Move  ...     2.0   52.71
# 13311            Plot  Area  Ready To Move  ...     2.0  250.00
# 13312  Super built-up  Area  Ready To Move  ...     2.0   47.00
# 13313  Super built-up  Area  Ready To Move  ...     1.0   57.00
# 13314  Super built-up  Area  Ready To Move  ...     3.0  112.00
# 13315        Built-up  Area  Ready To Move  ...     0.0  231.00
# 13316  Super built-up  Area  Ready To Move  ...     NaN  400.00
# 13317        Built-up  Area  Ready To Move  ...     1.0   60.00
# 13318  Super built-up  Area         18-Jun  ...     1.0  488.00
# 13319  Super built-up  Area  Ready To Move  ...     1.0   17.00
#
# [10 rows x 9 columns]

# %%
print(df.columns)
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
print(df.area_type)
# Out:
# 0        Super built-up  Area
# 1                  Plot  Area
# 2              Built-up  Area
# 3        Super built-up  Area
# 4        Super built-up  Area
#                  ...
# 13315          Built-up  Area
# 13316    Super built-up  Area
# 13317          Built-up  Area
# 13318    Super built-up  Area
# 13319    Super built-up  Area
# Name: area_type, Length: 13320, dtype: object

# %%
print(df[['area_type','location','size']])
# Out:
#                   area_type                  location       size
# 0      Super built-up  Area  Electronic City Phase II      2 BHK
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area               Uttarahalli      3 BHK
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK
# 4      Super built-up  Area                  Kothanur      2 BHK
# ...                     ...                       ...        ...
# 13315        Built-up  Area                Whitefield  5 Bedroom
# 13316  Super built-up  Area             Richards Town      4 BHK
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK
# 13319  Super built-up  Area              Doddathoguru      1 BHK
#
# [13320 rows x 3 columns]

# %%
print(df.head(4))
# Out:
#               area_type   availability  ... balcony   price
# 0  Super built-up  Area         19-Dec  ...     1.0   39.07
# 1            Plot  Area  Ready To Move  ...     3.0  120.00
# 2        Built-up  Area  Ready To Move  ...     3.0   62.00
# 3  Super built-up  Area  Ready To Move  ...     1.0   95.00
#
# [4 rows x 9 columns]

# %%
print(df.iloc[3:4])
# Out:
#               area_type   availability  ... balcony price
# 3  Super built-up  Area  Ready To Move  ...     1.0  95.0
#
# [1 rows x 9 columns]

# %%
print(df.iloc[4,5])
# Out:
# 1200

# %%
for index , row in df.iterrows():
  print(index, row['location'])
# Out:
# Streaming output truncated to the last 5000 lines.
# 8320 Venkatapura
# 8321 Electronic City Phase II
# 8322 Mathikere
# 8323 Haralur Road
# 8324 Harsha Layout
# 8325 Yelenahalli
# 8326 Bharathi Nagar
# 8327 Bommasandra Industrial Area
# 8328 Rajiv Nagar
# 8329 Dairy Circle
# 8330 7th Phase JP Nagar
# 8331 Kanakpura Road
# 8332 Sanjay nagar
# 8333 Begur Road
# 8334 1st Stage Indira Nagar
# 8335 Yarandahalli
# 8336 BTM 2nd Stage
# 8337 Electronic City
# 8338 Whitefield
# 8339 Rajiv Nagar
# 8340 Koramangala
# 8341 Kammanahalli
# 8342 Kacharakanahalli
# 8343 HBR Layout
# 8344 Electronic City Phase II
# 8345 Whitefield
# 8346 Bhoganhalli
# 8347 Ashwath Nagar
# 8348 Sahakara Nagar
# 8349 Electronic City
# 8350 Ananth Nagar
# 8351 Whitefield
# 8352 KR Puram
# 8353 Kengeri Satellite Town
# 8354 Kalyan nagar
# 8355 Kengeri
# 8356 Hennur Road
# 8357 OMBR Layout
# 8358 Balagere
# 8359 Marathahalli
# 8360 Subramanyapura
# 8361 Haralur Road
# 8362 Kanaka Nagar
# 8363 Old Madras Road
# ...

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df.sort_values('size', ascending=False)
# Out:
#             area_type          availability  ... balcony    price
# 6538       Plot  Area         Ready To Move  ...     3.0   185.00
# 648    Built-up  Area         Ready To Move  ...     NaN   265.00
# 1593       Plot  Area         Ready To Move  ...     0.0   360.00
# 1299       Plot  Area         Ready To Move  ...     1.0  1200.00
# 13221      Plot  Area         Ready To Move  ...     1.0    75.00
# ...               ...                   ...  ...     ...      ...
# 8565       Plot  Area  Immediate Possession  ...     NaN   120.00
# 8703       Plot  Area  Immediate Possession  ...     NaN    42.30
# 10634      Plot  Area  Immediate Possession  ...     NaN    31.11
# 11019      Plot  Area  Immediate Possession  ...     NaN    12.75
# 11569      Plot  Area  Immediate Possession  ...     NaN     8.44
#
# [13320 rows x 9 columns]

# %%
df.head(5)
# Out:
#               area_type   availability  ... balcony   price
# 0  Super built-up  Area         19-Dec  ...     1.0   39.07
# 1            Plot  Area  Ready To Move  ...     3.0  120.00
# 2        Built-up  Area  Ready To Move  ...     3.0   62.00
# 3  Super built-up  Area  Ready To Move  ...     1.0   95.00
# 4  Super built-up  Area  Ready To Move  ...     1.0   51.00
#
# [5 rows x 9 columns]

# %%
df['Total'] = df['bath'] + df['balcony']

# %%
df.head(5)
# Out:
#               area_type   availability  ...   price Total
# 0  Super built-up  Area         19-Dec  ...   39.07   3.0
# 1            Plot  Area  Ready To Move  ...  120.00   8.0
# 2        Built-up  Area  Ready To Move  ...   62.00   5.0
# 3  Super built-up  Area  Ready To Move  ...   95.00   4.0
# 4  Super built-up  Area  Ready To Move  ...   51.00   3.0
#
# [5 rows x 10 columns]

# %%
45+78+181+1232+45885
# Out:
# 47421

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
#  9   Total         12711 non-null  float64
# dtypes: float64(4), object(6)
# memory usage: 1.0+ MB

# %%
df.drop(columns=['size'])
# Out:
#                   area_type   availability  ...   price Total
# 0      Super built-up  Area         19-Dec  ...   39.07   3.0
# 1                Plot  Area  Ready To Move  ...  120.00   8.0
# 2            Built-up  Area  Ready To Move  ...   62.00   5.0
# 3      Super built-up  Area  Ready To Move  ...   95.00   4.0
# 4      Super built-up  Area  Ready To Move  ...   51.00   3.0
# ...                     ...            ...  ...     ...   ...
# 13315        Built-up  Area  Ready To Move  ...  231.00   4.0
# 13316  Super built-up  Area  Ready To Move  ...  400.00   NaN
# 13317        Built-up  Area  Ready To Move  ...   60.00   3.0
# 13318  Super built-up  Area         18-Jun  ...  488.00   5.0
# 13319  Super built-up  Area  Ready To Move  ...   17.00   2.0
#
# [13320 rows x 9 columns]

# %%
df.head()
# Out:
#               area_type   availability  ...   price Total
# 0  Super built-up  Area         19-Dec  ...   39.07   3.0
# 1            Plot  Area  Ready To Move  ...  120.00   8.0
# 2        Built-up  Area  Ready To Move  ...   62.00   5.0
# 3  Super built-up  Area  Ready To Move  ...   95.00   4.0
# 4  Super built-up  Area  Ready To Move  ...   51.00   3.0
#
# [5 rows x 10 columns]

# %%
df['size'] = df.iloc[: , 4:9].sum(axis=1)

# %%
df.head
# Out:
# <bound method NDFrame.head of                   area_type   availability  ...   price  Total
# 0      Super built-up  Area         19-Dec  ...   39.07    3.0
# 1                Plot  Area  Ready To Move  ...  120.00    8.0
# 2            Built-up  Area  Ready To Move  ...   62.00    5.0
# 3      Super built-up  Area  Ready To Move  ...   95.00    4.0
# 4      Super built-up  Area  Ready To Move  ...   51.00    3.0
# ...                     ...            ...  ...     ...    ...
# 13315        Built-up  Area  Ready To Move  ...  231.00    4.0
# 13316  Super built-up  Area  Ready To Move  ...  400.00    NaN
# 13317        Built-up  Area  Ready To Move  ...   60.00    3.0
# 13318  Super built-up  Area         18-Jun  ...  488.00    5.0
# 13319  Super built-up  Area  Ready To Move  ...   17.00    2.0
#
# [13320 rows x 10 columns]>

# %%
print(df['size'])
# Out:
# 0         42.07
# 1        128.00
# 2         67.00
# 3         99.00
# 4         54.00
#           ...
# 13315    235.00
# 13316    405.00
# 13317     63.00
# 13318    493.00
# 13319     19.00
# Name: size, Length: 13320, dtype: float64

# %%
df.to_csv('modified.csv')

# %%
df.head()
# Out:
#               area_type   availability  ...   price  Total
# 0  Super built-up  Area         19-Dec  ...   39.07    3.0
# 1            Plot  Area  Ready To Move  ...  120.00    8.0
# 2        Built-up  Area  Ready To Move  ...   62.00    5.0
# 3  Super built-up  Area  Ready To Move  ...   95.00    4.0
# 4  Super built-up  Area  Ready To Move  ...   51.00    3.0
#
# [5 rows x 10 columns]

# %%
df.location['bath'] = '2.0'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                   area_type   availability  ...   price  Total
# 0      Super built-up  Area         19-Dec  ...   39.07    3.0
# 1                Plot  Area  Ready To Move  ...  120.00    8.0
# 2            Built-up  Area  Ready To Move  ...   62.00    5.0
# 3      Super built-up  Area  Ready To Move  ...   95.00    4.0
# 4      Super built-up  Area  Ready To Move  ...   51.00    3.0
# ...                     ...            ...  ...     ...    ...
# 13315        Built-up  Area  Ready To Move  ...  231.00    4.0
# 13316  Super built-up  Area  Ready To Move  ...  400.00    NaN
# 13317        Built-up  Area  Ready To Move  ...   60.00    3.0
# 13318  Super built-up  Area         18-Jun  ...  488.00    5.0
# 13319  Super built-up  Area  Ready To Move  ...   17.00    2.0
#
# [13320 rows x 10 columns]

# %%
df.loc[df['availability'].str.contains('Ready To Move')]
# Out:
#                   area_type   availability  ...  price  Total
# 1                Plot  Area  Ready To Move  ...  120.0    8.0
# 2            Built-up  Area  Ready To Move  ...   62.0    5.0
# 3      Super built-up  Area  Ready To Move  ...   95.0    4.0
# 4      Super built-up  Area  Ready To Move  ...   51.0    3.0
# 5      Super built-up  Area  Ready To Move  ...   38.0    3.0
# ...                     ...            ...  ...    ...    ...
# 13314  Super built-up  Area  Ready To Move  ...  112.0    6.0
# 13315        Built-up  Area  Ready To Move  ...  231.0    4.0
# 13316  Super built-up  Area  Ready To Move  ...  400.0    NaN
# 13317        Built-up  Area  Ready To Move  ...   60.0    3.0
# 13319  Super built-up  Area  Ready To Move  ...   17.0    2.0
#
# [10581 rows x 10 columns]

# %%
df.loc[~df['availability'].str.contains('Ready To Move')]
# Out:
#                   area_type availability  ...   price  Total
# 0      Super built-up  Area       19-Dec  ...   39.07    3.0
# 6      Super built-up  Area       18-May  ...  204.00    NaN
# 10     Super built-up  Area       18-Feb  ...   70.00    4.0
# 21     Super built-up  Area       19-Dec  ...  122.00    4.0
# 24     Super built-up  Area       18-Nov  ...   25.25    1.0
# ...                     ...          ...  ...     ...    ...
# 13291            Plot  Area       18-Jan  ...   26.00    1.0
# 13292  Super built-up  Area       18-Jul  ...   63.93    4.0
# 13295  Super built-up  Area       18-Feb  ...  112.00    5.0
# 13299  Super built-up  Area       18-Dec  ...  154.50    5.0
# 13318  Super built-up  Area       18-Jun  ...  488.00    5.0
#
# [2739 rows x 10 columns]

# %%
df.head()
# Out:
#               area_type   availability  ...   price  Total
# 0  Super built-up  Area         19-Dec  ...   39.07    3.0
# 1            Plot  Area  Ready To Move  ...  120.00    8.0
# 2        Built-up  Area  Ready To Move  ...   62.00    5.0
# 3  Super built-up  Area  Ready To Move  ...   95.00    4.0
# 4  Super built-up  Area  Ready To Move  ...   51.00    3.0
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13320 non-null  float64
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
#  9   Total         12711 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 1.0+ MB

# %%
df.groupby(['balcony']).mean().sort_values('price', ascending=False)
df.groupby(['balcony']).mean().sort_values('bath', ascending=True)
df.groupby(['balcony']).mean().sort_values('Total', ascending=True)
df.groupby(['balcony']).mean().sort_values('size', ascending=True)
# Out:
#                size      bath       price     Total
# balcony
# 1.0       89.012685  2.282622   85.730063  3.282622
# 0.0      113.401093  2.702624  110.698469  2.702624
# 2.0      114.680364  2.698416  109.981948  4.698416
# 3.0      157.046017  3.297249  150.748768  6.297249

# %%
df.groupby(['size']).count()
# Out:
#          area_type  availability  location  ...  price  Total  count
# size                                        ...
# 8.44             1             1         1  ...      1      0      1
# 10.00            1             1         1  ...      1      1      1
# 11.00            1             1         1  ...      1      1      1
# 11.50            1             1         1  ...      1      1      1
# 12.00            4             4         4  ...      4      4      4
# ...            ...           ...       ...  ...    ...    ...    ...
# 2708.00          1             1         1  ...      1      1      1
# 2745.00          1             1         1  ...      1      1      1
# 2809.00          1             1         1  ...      1      1      1
# 2919.00          1             1         1  ...      1      1      1
# 3613.00          1             1         1  ...      1      0      1
#
# [2226 rows x 10 columns]

# %%
df['count'] = 2

# %%
df
# Out:
#                   area_type   availability  ... Total  count
# 0      Super built-up  Area         19-Dec  ...   3.0      2
# 1                Plot  Area  Ready To Move  ...   8.0      2
# 2            Built-up  Area  Ready To Move  ...   5.0      2
# 3      Super built-up  Area  Ready To Move  ...   4.0      2
# 4      Super built-up  Area  Ready To Move  ...   3.0      2
# ...                     ...            ...  ...   ...    ...
# 13315        Built-up  Area  Ready To Move  ...   4.0      2
# 13316  Super built-up  Area  Ready To Move  ...   NaN      2
# 13317        Built-up  Area  Ready To Move  ...   3.0      2
# 13318  Super built-up  Area         18-Jun  ...   5.0      2
# 13319  Super built-up  Area  Ready To Move  ...   2.0      2
#
# [13320 rows x 11 columns]

# %%
for df in pd.read_csv('house prediction.csv', chunksize=5):
  print('chunk df')
  print(df)
# Out:
# Streaming output truncated to the last 5000 lines.
# 10542  Built-up  Area  Ready To Move  ...     0.0  150.00
# 10543      Plot  Area  Ready To Move  ...     NaN  250.00
# 10544      Plot  Area  Ready To Move  ...     2.0  200.00
#
# [5 rows x 9 columns]
# chunk df
#                   area_type   availability  ... balcony price
# 10545        Built-up  Area  Ready To Move  ...       1    90
# 10546  Super built-up  Area  Ready To Move  ...       1    65
# 10547  Super built-up  Area  Ready To Move  ...       3    55
# 10548        Built-up  Area  Ready To Move  ...       2    80
# 10549            Plot  Area  Ready To Move  ...       1    70
#
# [5 rows x 9 columns]
# chunk df
#                   area_type   availability  ... balcony price
# 10550  Super built-up  Area         20-Apr  ...     1.0    35
# 10551  Super built-up  Area  Ready To Move  ...     2.0   121
# 10552            Plot  Area  Ready To Move  ...     0.0   130
# ...
